# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values


y = y.reshape(len(y),1)


from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()

X1 = sc_X.fit_transform(X)
y1 = sc_y.fit_transform(y)


from sklearn.svm import SVR

regressor = SVR( kernel = 'rbf' )


regressor.fit(X1,y1)


sc_y.inverse_transform( regressor.predict( sc_X.transform([[6.5]]) ).reshape(-1,1) )
# Out:
# /Users/radeonxfx/miniforge3/lib/python3.10/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([[170370.0204065]])

# %%
X1 , regressor.predict( X1 )
# Out:
# (array([[-1.5666989 ],
#         [-1.21854359],
#         [-0.87038828],
#         [-0.52223297],
#         [-0.17407766],
#         [ 0.17407766],
#         [ 0.52223297],
#         [ 0.87038828],
#         [ 1.21854359],
#         [ 1.5666989 ]]),
#  array([-0.6197853 , -0.62924694, -0.56788994, -0.49732233, -0.44690338,
#         -0.36617206, -0.14115569,  0.28557658,  0.78226531,  1.08559794]))

# %%
# plt.scatter( X,y  )
# plt.plot( X , sc_y.inverse_transform( regressor.predict( X1 ).reshape(-1,1) ) )
# plt.plot( sc_X.inverse_transform(X1) , 
#         sc_y.inverse_transform( regressor.predict( X1 ).reshape(-1,1) )  )


X_grid = np.arange(min( sc_X.inverse_transform(X1)) , max(sc_X.inverse_transform(X1) ) , 0.1 )
X_grid = X_grid.reshape(len(X_grid) ,1 )
X_grid

plt.scatter( sc_X.inverse_transform(X1) , sc_y.inverse_transform(y1) )  
plt.plot( X_grid , sc_y.inverse_transform(  regressor.predict( sc_X.transform(X_grid) ).reshape(-1,1)  )  )
# Out:
# /var/folders/15/p551z5bx22l9wb197m4k8bqm0000gn/T/ipykernel_3278/3419717429.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min( sc_X.inverse_transform(X1)) , max(sc_X.inverse_transform(X1) ) , 0.1 )

# %%
# sc_X.inverse_transform(X_grid)
# Out:
# array([[ 8.37228132],
#        [ 8.65950946],
#        [ 8.94673759],
#        [ 9.23396572],
#        [ 9.52119385],
#        [ 9.80842198],
#        [10.09565012],
#        [10.38287825],
#        [10.67010638],
#        [10.95733451],
#        [11.24456265],
#        [11.53179078],
#        [11.81901891],
#        [12.10624704],
#        [12.39347518],
#        [12.68070331],
#        [12.96793144],
#        [13.25515957],
#        [13.54238771],
#        [13.82961584],
#        [14.11684397],
#        [14.4040721 ],
#        [14.69130023],
#        [14.97852837],
#        [15.2657565 ],
#        [15.55298463],
#        [15.84021276],
#        [16.1274409 ],
#        [16.41466903],
#        [16.70189716],
#        [16.98912529],
#        [17.27635343],
#        [17.56358156],
#        [17.85080969],
#        [18.13803782],
#        [18.42526595],
#        [18.71249409],
#        [18.99972222],
#        [19.28695035],
#        [19.57417848],
#        [19.86140662],
#        [20.14863475],
#        [20.43586288],
#        [20.72309101],
#        [21.01031915],
#        [21.29754728],
#        [21.58477541],
#        [21.87200354],
#        [22.15923167],
#        [22.44645981],
#        [22.73368794],
#        [23.02091607],
#        [23.3081442 ],
#        [23.59537234],
#        [23.88260047],
#        [24.1698286 ],
#        [24.45705673],
#        [24.74428487],
#        [25.031513  ],
#        [25.31874113],
#        [25.60596926],
#        [25.8931974 ],
#        [26.18042553],
#        [26.46765366],
#        [26.75488179],
#        [27.04210992],
#        [27.32933806],
#        [27.61656619],
#        [27.90379432],
#        [28.19102245],
#        [28.47825059],
#        [28.76547872],
#        [29.05270685],
#        [29.33993498],
#        [29.62716312],
#        [29.91439125],
#        [30.20161938],
#        [30.48884751],
#        [30.77607564],
#        [31.06330378],
#        [31.35053191],
#        [31.63776004],
#        [31.92498817],
#        [32.21221631],
#        [32.49944444],
#        [32.78667257],
#        [33.0739007 ],
#        [33.36112884],
#        [33.64835697],
#        [33.9355851 ]])

# %%
X_grid = np.arange( min(X) , max(X) , 0.1  )
X_grid = X_grid.reshape( len(X_grid), 1 )


plt.scatter( X, y )
plt.plot( X_grid, regressor.predict(X_grid) )
# Out:
# /var/folders/15/p551z5bx22l9wb197m4k8bqm0000gn/T/ipykernel_3278/4046907321.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange( min(X) , max(X) , 0.1  )

# %%
import numpy as np
import matplotlib.ipynb as plt
import pandas as pd


dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values 

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor( n_estimates = 10 , random_state = )


regres
