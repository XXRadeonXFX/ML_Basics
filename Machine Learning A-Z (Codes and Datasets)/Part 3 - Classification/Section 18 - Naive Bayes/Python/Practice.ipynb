# %%
total = 100

mach1 = 60 
mach2 = 40

mach1 ,mach2
# Out:
# (0.6, 0.4)

# %%
bad = 1
mach1_b = 0.5 
mach2_b = 0.5 




# -> 1000
# -> 10

# 5 / 5




# 0.5 / 0.6


0.5/40 * 100  , 0.5/60 * 100
# Out:
# (1.25, 0.8333333333333334)

# %%
(1/20) * (20/30) * 30/4
# Out:
# 0.25

# %%
(3/10) * (10/30) * 30/4
# Out:
# 0.7499999999999999

# %%
# Out:
# 3.0
