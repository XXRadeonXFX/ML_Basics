# %%
pip install seaborn

# %%
  import numpy as np
  import pandas as pd
  import matplotlib.pyplot as plt
  import seaborn as sns

# %%
dataset = pd.read_csv('titanic.csv')

# %%
sec_a = np.array([75,65,73,68,72,76])
sec_b = np.array([90,47,43,96,93,51])

no = np.array([1,2,3,4,5,6])

# %%
np.std(sec_a) , np.std(sec_b)
# Out:
# (3.8622100754188224, 23.18045153428495)

# %%
np.var(sec_a) , np.var(sec_b)
# Out:
# (14.916666666666666, 537.3333333333334)

# %%
np.var(sec_a) , np.var(sec_b)
# Out:
# (14.916666666666666, 537.3333333333334)

# %%
dataset.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            2         1       1
# 1            4         1       1
# 2            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 0      0  PC 17599  71.2833   C85        C
# 1      0    113803  53.1000  C123        S
# 2      0     17463  51.8625   E46        S

# %%
np.var(dataset['Age'])
# Out:
# 243.39321702051421

# %%
dataset['Age'].value_counts()
# Out:
# Age
# 36.0    11
# 24.0     9
# 19.0     6
# 35.0     6
# 31.0     5
#         ..
# 71.0     1
# 3.0      1
# 1.0      1
# 36.5     1
# 26.0     1
# Name: count, Length: 63, dtype: int64

# %%
sns.histplot(x="Age", data=dataset , bins = [x for x in range(0,100,10)] )
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(10,3) )

plt.scatter( sec_a,  np.array([ x for x in range(1,7)] )  , label = 'SEC_A'  )
plt.scatter( sec_b , np.array( [ 1,2,3,4,5,6 ]) , label = 'SEC_B'  )


plt.plot( np.array( [ mean for x in range(1,7) ]   )  , no , label = 'Mean' )

plt.legend()
plt.show()

# %%
mean = np.mean(sec_b)
mean
# Out:
# 70.0

# %%
# Mean Absolute Division
mad_a =  np.sum(abs(sec_a - mean)) / len(sec_a)
mad_a
# Out:
# 3.8333333333333335

# %%
# Mean Absolute Division
mad_b = np.sum(abs(sec_b - mean))/len(sec_b)
mad_b
# Out:
# 23.0

# %%
# WE use std. devision to find the spread of the data instead of MAD
np.std(sec_a) , np.var(sec_a)
# Out:
# (3.8622100754188224, 14.916666666666666)

# %%
np.std(sec_b) , np.var(sec_b)
# Out:
# (23.18045153428495, 537.3333333333334)
