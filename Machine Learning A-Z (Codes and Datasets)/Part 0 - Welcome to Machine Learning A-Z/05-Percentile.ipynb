# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("titanic_dirty.csv")


dataset.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex            18
# Age            35
# SibSp           0
# Parch           0
# Ticket          0
# Fare           23
# Cabin          21
# Embarked       11
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex            18
# Age            35
# SibSp           0
# Parch           0
# Ticket          0
# Fare           23
# Cabin          21
# Embarked       11
# dtype: int64

# %%
dataset['Age'].fillna(dataset['Age'].mean(), inplace=True)
dataset.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex            18
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare           23
# Cabin          21
# Embarked       11
# dtype: int64

# %%
( np.percentile(
    dataset['Age'], 25
) , 
np.percentile(
    dataset['Age'],75
) ,
np.percentile(
    dataset['Age'], 0
) ,
np.percentile(
    dataset['Age'],50
))
# Out:
# (27.0, 45.25, 0.92, 35.90148648648649)

# %%
dataset['Age'].min() , dataset['Age'].max()
# Out:
# (0.92, 80.0)

# %%
dataset['Age'].median()
# Out:
# 35.90148648648649

# %%
sns.boxplot(x='Age' , data=dataset )
plt.show()

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.901486    0.464481
# std     247.052476    0.470725    0.515187   14.459477    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   27.000000    0.000000
# 50%     457.000000    1.000000    1.000000   35.901486    0.000000
# 75%     676.000000    1.000000    1.000000   45.250000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  160.000000
# mean     0.475410   79.849064
# std      0.754617   77.122051
# min      0.000000    0.000000
# 25%      0.000000   30.000000
# 50%      0.000000   57.000000
# 75%      1.000000   90.269800
# max      4.000000  512.329200

# %%
sns.boxplot(x='Fare' ,data=dataset) 
sns.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [59], in <cell line: 2>()
#       1 sns.boxplot(x='Fare' ,data=dataset)
# ----> 2 sns.show()
#
# AttributeError: module 'seaborn' has no attribute 'show'
